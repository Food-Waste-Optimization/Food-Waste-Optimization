# %%
# %cd ../../

# %%
import polars as pl

# %%
dim_meal_types = pl.from_dicts([
    {'meal_type_id': 1,	'meal_type': "Kala",        'meal_type_en': "fish",},
    {'meal_type_id': 2,	'meal_type': "Liha",        'meal_type_en': "meat",},
    {'meal_type_id': 3,	'meal_type': "Kana",        'meal_type_en': "chicken",},
    {'meal_type_id': 4,	'meal_type': "Vegaani",     'meal_type_en': "vegan",},
    {'meal_type_id': 5,	'meal_type': "Kasvis",      'meal_type_en': "vegetarian",},
    {'meal_type_id': 6,	'meal_type': "Buffet",      'meal_type_en': "buffet",},
    {'meal_type_id': 7,	'meal_type': "Not Mapped",  'meal_type_en': "not_mapped",},
])

dim_meal_types.head()

# %%
path = "data/processed/dim_meal_types.xlsx"
dim_meal_types.write_excel(path)
