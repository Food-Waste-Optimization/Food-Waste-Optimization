# %%
# %cd ../../

# %%
import polars as pl

# %%
dim_restaurants = pl.from_dicts([
    {'restaurant_id':1,	'restaurant': "600 Chemicum",   'restaurant_short': "che",},
    {'restaurant_id':2,	'restaurant': "620 Exactum",    'restaurant_short': "exa",},
    {'restaurant_id':3,	'restaurant': "610 Physicum",   'restaurant_short': "phy",},
    {'restaurant_id':4,	'restaurant': "570 Viikuna",    'restaurant_short': "vik",},
])

dim_restaurants.head()

# %%
path = "data/processed/dim_restaurants.xlsx"
dim_restaurants.write_excel(path)
